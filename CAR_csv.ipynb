# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

# Cargar el dataset
df = pd.read_csv('C:/Users/Zephyrus/Downloads/car_models(1).csv')

# Información básica del dataset
print(df.head())  
print(df.tail())  
print(df.info())  
print(df.describe())  

# Manejo de valores nulos
print(df.isnull().sum())  

# Rellenar valores nulos en 'Modelo' con el valor más frecuente
df['Modelo'].fillna(df['Modelo'].mode()[0], inplace=True)

# O eliminar filas con valores nulos
# df.dropna(inplace=True)

# Transformación y limpieza de datos
df['Modelo del Motor'] = df['Modelo del Motor'].astype('category')
df.drop_duplicates(inplace=True)
df['Promedio de precios (USD)'] = df['Precio Actual de Mercado (USD)'] / df['Precio de Lanzamiento (USD)']
# Out:
#          Marca       Modelo  Categoría  Cilindros  Cilindrada (cc)  \
# 0      Ferrari          F40  Deportivo          8             2936
# 1  Lamborghini    Aventador  Superauto         12             6498
# 2      Porsche    911 Turbo  Deportivo          6             3745
# 3         Ford   Mustang GT  Deportivo          8             4951
# 4    Chevrolet  Corvette C8  Deportivo          8             6162
#
#   Modelo del Motor  Precio de Lanzamiento (USD)  \
# 0            F120A                       400000
# 1             L539                       393695
# 2           MA1/69                       200000
# 3        Coyote V8                        30000
# 4              LT2                        60000
#
#    Precio Actual de Mercado (USD)  Año de Lanzamiento
# 0                         1500000                1987
# 1                          500000                2011
# 2                          250000                1974
# 3                           55000                1964
# 4                           65000                2020
#             Marca  Modelo  Categoría  Cilindros  Cilindrada (cc)  \
# 10         Toyota   Supra  Deportivo          6             2998
# 11         Nissan    GT-R  Superauto          6             3799
# 12            BMW      M3  Deportivo          6             2993
# 13  Mercedes-Benz  AMG GT  Deportivo          8             3982
# 14          Mazda    MX-5  Deportivo          4             1998
#
#    Modelo del Motor  Precio de Lanzamiento (USD)  \
# 10          2JZ-GTE                        50000
# 11         VR38DETT                       113540
# 12              S58                        70000
# 13             M178                       115000
# 14       SkyActiv-G                        26000
#
#     Precio Actual de Mercado (USD)  Año de Lanzamiento
# 10                           65000                1993
# 11                          120000                2007
# 12                           75000                1986
# 13                          130000                2014
# 14                           30000                1989
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Marca                           15 non-null     object
#  1   Modelo                          15 non-null     object
#  2   Categoría                       15 non-null     object
#  3   Cilindros                       15 non-null     int64
#  4   Cilindrada (cc)                 15 non-null     int64
#  5   Modelo del Motor                15 non-null     object
#  6   Precio de Lanzamiento (USD)     15 non-null     int64
#  7   Precio Actual de Mercado (USD)  15 non-null     int64
#  8   Año de Lanzamiento              15 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 1.2+ KB
# None
#        Cilindros  Cilindrada (cc)  Precio de Lanzamiento (USD)  \
# count  15.000000        15.000000                 1.500000e+01
# mean    7.733333      4227.666667                 2.568157e+05
# std     3.692979      2006.649933                 4.180140e+05
# min     0.000000         0.000000                 2.600000e+04
# 25%     6.000000      2995.500000                 6.000000e+04
# 50%     8.000000      3982.000000                 1.150000e+05
# 75%     8.000000      5683.000000                 2.520000e+05
# max    16.000000      7993.000000                 1.700000e+06
#
#        Precio Actual de Mercado (USD)  Año de Lanzamiento
# count                    1.500000e+01           15.000000
# mean                     3.946667e+05         2001.333333
# std                      6.888538e+05           17.958948
# min                      3.000000e+04         1964.000000
# 25%                      6.750000e+04         1988.000000
# 50%                      1.200000e+05         2007.000000
# 75%                      2.500000e+05         2016.000000
# max                      2.500000e+06         2021.000000
# Marca                             0
# Modelo                            0
# Categoría                         0
# Cilindros                         0
# Cilindrada (cc)                   0
# Modelo del Motor                  0
# Precio de Lanzamiento (USD)       0
# Precio Actual de Mercado (USD)    0
# Año de Lanzamiento                0
# dtype: int64
# C:\Users\Zephyrus\AppData\Local\Temp\ipykernel_7768\2851999843.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Modelo'].fillna(df['Modelo'].mode()[0], inplace=True)

# %%
sns.histplot(df['Precio Actual de Mercado (USD)'])  
plt.show()

# %%
sns.boxplot(x=df['Precio de Lanzamiento (USD)'])  
plt.show()

# %%
sns.countplot(x='Categoría', data=df)  
plt.show()

# %%
sns.scatterplot(x='Año de Lanzamiento', y='Precio Actual de Mercado (USD)', data=df)  
plt.show()

# %%
sns.barplot(x='Categoría', y='Cilindros', data=df)  
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True))  
plt.show()
